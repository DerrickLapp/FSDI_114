# %% [markdown]
# # Problem 1
#
# ## Anagram Check
# Create a function, `anagram_check`, that receives two arguments of type string and determines if these are anagrams of each other (criteria below), returning `True` if these are anagrams of each other, `False` otherwise.
#
# ## Criteria
# Two strings are anagrams of each other if, and only if, all the criteria below are met:
# 1. They must contain the same amount of letters.
# 2. They must use the same letters the same amount of times.
#
# ## Examples
# ```
# heart and earth
# cars and scar
# rats and star
# ```
#
# ## Note
# The three examples above are just examples, there may be other strings (many) that meet the criteria above.

# %% [markdown]
# ## Assessment and Assembly
#
# ![image.png](attachment:7382305e-ccae-4936-8155-71f585dbc58b.png)
#
#
# <!-- I'm thinking we need to make two lists, then append each word into the lists; -->
# Strings are inherently lists so we may not need to make them such
#
# Check the size of each string to see if they are the same size;
#
# Then using one string, get the value of the head of the string and search the second string to find that value, and remove it from the second string;
#
# Then move on to the next letter in the first string and loop that process until you reach the end of the first string or you fail to find a value that matches (meaning same letters used different number of times or different letters used)
#
# If all letters match when getting to the end of the first string (something like if current.next == None), then return True
#
# Tips from Eduardo's presentation when called upon:
# Remove uppercase and spaces from the strings
#
# Tips from Nick's presentation when called upon:
# len(str1) and len(str2)
#
# Tips from my own presentation:
# put each string into its own dictionary and then compare dictionaries (keys are letters: values are number of times those letters appear).
#
# # Don't do this (don't use clever solutions)
# def anagram_check(str1,str2):
#
#         return sorted(str1.replace(" ","").lower() == sorted(str2.replace(" ","").lower())
# # It shows you memorized built ins but not necessarily that you know how to solve the problems

# %%
def anagram_check(string1, string2):
    str1 = string1.replace(" ","").lower()
    str2 = string2.replace(" ","").lower()
    if len(str1) != len(str2):
        return False
    else:
        # Make lists of letters and count them
        str1letters = []
        str2letters = []
        for char in str1:
            found = False
            for letter in str1letters:
                if letter[0] == char:
                    letter[1] += 1
                    found = True
                    break
            if not found:
                str1letters.append([char, 1])
        for char in str2:
            found = False
            for letter in str2letters:
                if letter[0] == char:
                    letter[1] += 1
                    found = True
                    break
            if not found:
                str2letters.append([char, 1])  
        # Turn lists into dictionaries for each string
        str1dict = {letter[0]: letter[1] for letter in str1letters}
        str2dict = {letter[0]: letter[1] for letter in str2letters}
        # Compare dictionaries
        if str1dict == str2dict:
            # print(str1dict)
            # print(str2dict)
            return True
        else:
            print(str1dict)
            print(str2dict)
            return False

# %%
print(anagram_check("I am Lord Voldemort","Tom Marvolo Riddle"))
print(anagram_check("The Morse Code", "Here Come Dots" ))
print(anagram_check("Same Number of letters", "This nineteen letters"))
# Out:
# True
# True
# {'s': 2, 'a': 1, 'm': 2, 'e': 4, 'n': 1, 'u': 1, 'b': 1, 'r': 2, 'o': 1, 'f': 1, 'l': 1, 't': 2}
# {'t': 4, 'h': 1, 'i': 2, 's': 2, 'n': 3, 'e': 5, 'l': 1, 'r': 1}
# False

# %%
# Prof Rafael version
#Pseudocode version

#define function "anagram_check" with params string1 and string2:
#   string1 = string1 without spaces and in lower case
#   string2 = string2 without spaces and in lower case
#   if the length of string1 is not equal to the length of string2:
#          return False
#    otherwise:
#        d1 = new dictionary
#        d2 = new dicionary
#        for each "number" in the range from 0 to the length of string:
#                if the character at position "number" in string 1 is not in d1:
#                    add that character to d1 as a key, and set its value to 1     #indicating we've seen this character once
#                otherwise:
#                    add 1 to the value associated with this character             #indicating we've seen it more than once
#        for each "number" in the range from 0 to the length of string:
#                if the character at position "nubmer" in string 2 is not in d2:
#                    add that character to d2 as a key, and set its value to 1     #indicating we've seen this character once
#                otherwise:
#                    add 1 to the value associated with this character             #indicating we've seen it more than once
#         if d1 == d2:
#              return True
#         otherwise:
#               return False

# Just a test, unfinished and not working
# def prof_anagram_check(string1, string2):
#     str1 = string1.replace(" ","").lower()
#     str2 = string2.replace(" ","").lower()
#     if len(str1) != len(str2):
#         return False
#     else:
#         # Make dictionaries of letters and count them
#         str1letters = {}
#         str2letters = {}
#         for letter in str1:
#             if letter in str1letters[letter] += 1
#         else:
#             str1letters[letter] = 1
#             if letter in str2letters[letter] += 1
#         else:
#             str2letters[letter] = 1
#         # Compare dictionaries
#         if str1dict == str2dict:
#             # print(str1dict)
#             # print(str2dict)
#             return True
#         else:
#             print(str1dict)
#             print(str2dict)
#             return False

# %% [markdown]
# # Final Problem
#
# Given what you've learned about singly linked lists:
# 1. First: copy the Singly Linked List from class 3, then
# 2. Update it, so that it uses a doubly linked node,
# 3. Then: complete the operations.
#
#
# ## Note
# You will need to `refactor` the code to get it to work, as each operation is now twice as complex.

# %% [markdown]
# ![image.png](attachment:d8742976-4beb-46b0-8d5b-0a3a7e200f67.png)

# %%
# From scratch implementation of DoublyLinkList

class DoublyLinkedList:
    class __Node:
        def __init__(self,datum):
            self.datum = datum
            self.next = None
            self.before = None

    def __init__(self):
        self.head = None
        self.tail = None
        self.count = 0

    def append(self, value):
        new_node = self.__Node(value)
        self.count += 1
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.before = self.tail
            self.tail = new_node

    def insert(self, index, value):
        # This method inserts a new node with the "value" BEFORE the given "index".
        ref1 = self.head
        ref2 = 0
        ref3 = ref1.next
        new_node = self.__Node(value)
        if not self.head or index > self.count:
            self.append(value)
        elif index == 0:
            self.count += 1
            self.head.before = new_node
            new_node.next = self.head
            self.head = new_node
        elif index < 0:
            raise IndexError("Please refrain from using a negative number")
        else:
            self.count += 1
            while ref1 and ref2 !=index:
                if ref2 == index-1:
                    new_node.next = ref1.next
                    new_node.before = ref1
                    ref3.before = new_node
                    ref1.next = new_node
                    break
                ref1 = ref1.next
                ref2 += 1
                ref3 = ref3.next
            return
            
    def remove(self, value):
        # This method removes the first instance of "value" and raises a ValueError if the value is not present in the list.
        current = self.head
        found = False
        prev = current.before
        next_in_line = current.next
        while current.next and not found:
            if current.datum == value:
                found = True
            else:
                prev = current
                current = next_in_line
        if found:
            self.count -= 1
            if not prev:
                #This means the target value is at the head of our list
                self.head = self.head.next
                self.head.before = None
            else:
                # This means the target value is somewhere in the middle or the tail of the list
                prev.next = current.next
                next_in_line.before = prev
                if current == self.tail:
                    self.tail = prev
                    self.tail.next = None
            if not self.head:
                self.tail = None
            else:
                raise ValueError("Target value not found")
                                

    def index(self, value):
        # This method returns the position in the list of the given "value" if it is present in the list
        # Otherwise, it raises a ValueError if the value is not present in the list
        ref1 = self.head
        ref2 = 0
        found = False
        while ref1 and not found:
            if ref1.datum == value:
                found = True
            else:
                ref2 += 1
                ref1 = ref1.next
        if found:
            return ref1
        raise ValueError("Value not found")

    def search(self, index):
        if self.head:
            current = self.head
            iteration = 0
            while current and iteration != index:
                if iteration == index:
                    break
                current = current.next
                iteration += 1
            return current.datum
        raise IndexError("This list is empty")
    
    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % current.datum
            current = current.next
            while current:
                out += ", %s" % current.datum
                current = current.next
        out += "]"
        return out

    def __len__(self):
        # This method should return the total number of Nodes in this list.
        return self.count

# %%
dll = DoublyLinkedList()
print(dll)

dll.append(1)
print(dll)

dll.append(2)
print(dll)

dll.insert(1, "A")
print(dll)
print(dll.count)
# Out:
# []
# [1]
# [1, 2]
# [1, A, 2]
# 3
